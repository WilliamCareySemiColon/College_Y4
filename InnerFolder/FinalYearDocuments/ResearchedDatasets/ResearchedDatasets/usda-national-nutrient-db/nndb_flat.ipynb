# %%
import pandas as pd
import numpy as np

df = pd.read_csv("nndb_flat.csv")

df.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip CommonName MfgName ScientificName  Energy_kcal  \
# 0              Butter, salted        NaN     NaN            NaN          717
# 1  Butter, whipped, with salt        NaN     NaN            NaN          717
# 2       Butter oil, anhydrous        NaN     NaN            NaN          876
# 3                Cheese, blue        NaN     NaN            NaN          353
# 4               Cheese, brick        NaN     NaN            NaN          371
#
#    Protein_g  Fat_g  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  \
# 0       0.85  81.11  ...        0.0075      0.002625          0.026154
# ...

# %%
df[['FoodGroup','ShortDescrip']][df.FoodGroup == 'Dairy and Egg Products']
# Out:
#                    FoodGroup  \
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# 5     Dairy and Egg Products
# 6     Dairy and Egg Products
# 7     Dairy and Egg Products
# 8     Dairy and Egg Products
# 9     Dairy and Egg Products
# 10    Dairy and Egg Products
# 11    Dairy and Egg Products
# 12    Dairy and Egg Products
# 13    Dairy and Egg Products
# 14    Dairy and Egg Products
# 15    Dairy and Egg Products
# 16    Dairy and Egg Products
# 17    Dairy and Egg Products
# 18    Dairy and Egg Products
# 19    Dairy and Egg Products
# 20    Dairy and Egg Products
# 21    Dairy and Egg Products
# 22    Dairy and Egg Products
# 23    Dairy and Egg Products
# 24    Dairy and Egg Products
# 25    Dairy and Egg Products
# 26    Dairy and Egg Products
# 27    Dairy and Egg Products
# 28    Dairy and Egg Products
# 29    Dairy and Egg Products
# ...                      ...
# ...

# %%
list(df.columns)
# Out:
# ['ID',
#  'FoodGroup',
#  'ShortDescrip',
#  'Descrip',
#  'CommonName',
#  'MfgName',
#  'ScientificName',
#  'Energy_kcal',
#  'Protein_g',
#  'Fat_g',
#  'Carb_g',
#  'Sugar_g',
#  'Fiber_g',
#  'VitA_mcg',
#  'VitB6_mg',
#  'VitB12_mcg',
#  'VitC_mg',
#  'VitE_mg',
#  'Folate_mcg',
#  'Niacin_mg',
#  'Riboflavin_mg',
#  'Thiamin_mg',
#  'Calcium_mg',
#  'Copper_mcg',
#  'Iron_mg',
#  'Magnesium_mg',
#  'Manganese_mg',
#  'Phosphorus_mg',
#  'Selenium_mcg',
#  'Zinc_mg',
#  'VitA_USRDA',
#  'VitB6_USRDA',
#  'VitB12_USRDA',
#  'VitC_USRDA',
#  'VitE_USRDA',
#  'Folate_USRDA',
#  'Niacin_USRDA',
#  'Riboflavin_USRDA',
#  'Thiamin_USRDA',
#  'Calcium_USRDA',
#  'Copper_USRDA',
#  'Magnesium_USRDA',
#  'Phosphorus_USRDA',
#  'Selenium_USRDA',
#  'Zinc_USRDA']

# %%
df2 = df[['ID','FoodGroup','ShortDescrip','Descrip','Energy_kcal','Protein_g','Fat_g','Carb_g','Sugar_g','Fiber_g']]

# %%
for key in df2.columns:
    print(df2[key].describe())
    print("\n")

df2.head()
# Out:
# count     8618.000000
# mean     15467.757368
# std       9221.428766
# min       1001.000000
# 25%       8695.250000
# 50%      14273.000000
# 75%      20050.750000
# max      93600.000000
# Name: ID, dtype: float64
#
#
# count              8618
# unique               25
# top       Beef Products
# freq                946
# Name: FoodGroup, dtype: object
#
#
# count                                                  8618
# unique                                                 8614
# top       BEEF,CHUCK,UNDER BLADE CNTR STEAK,BNLESS,DENVE...
# freq                                                      2
# Name: ShortDescrip, dtype: object
#
#
# count                                 8618
# unique                                8618
# top       Soup, stock, fish, home-prepared
# freq                                     1
# Name: Descrip, dtype: object
#
#
# count    8618.000000
# mean      226.438617
# std       169.388910
# min         0.000000
# 25%        93.000000
# ...

# %%
df2.FoodGroup.value_counts()
# Out:
# Beef Products                          946
# Vegetables and Vegetable Products      828
# Baked Products                         797
# Soups, Sauces, and Gravies             452
# Lamb, Veal, and Game Products          438
# Poultry Products                       390
# Legumes and Legume Products            389
# Fast Foods                             371
# Breakfast Cereals                      363
# Baby Foods                             362
# Sweets                                 347
# Fruits and Fruit Juices                346
# Pork Products                          343
# Beverages                              315
# Finfish and Shellfish Products         267
# Dairy and Egg Products                 264
# Sausages and Luncheon Meats            244
# Fats and Oils                          219
# Cereal Grains and Pasta                183
# Snacks                                 171
# American Indian/Alaska Native Foods    165
# Nut and Seed Products                  133
# ...

# %%
df2.FoodGroup.describe()
# Out:
# count              8618
# unique               25
# top       Beef Products
# freq                946
# Name: FoodGroup, dtype: object

# %%
df.ShortDescrip
# Out:
# 0                                        BUTTER,WITH SALT
# 1                                BUTTER,WHIPPED,WITH SALT
# 2                                    BUTTER OIL,ANHYDROUS
# 3                                             CHEESE,BLUE
# 4                                            CHEESE,BRICK
# 5                                             CHEESE,BRIE
# 6                                        CHEESE,CAMEMBERT
# 7                                          CHEESE,CARAWAY
# 8                                          CHEESE,CHEDDAR
# 9                                         CHEESE,CHESHIRE
# 10                                           CHEESE,COLBY
# 11                    CHEESE,COTTAGE,CRMD,LRG OR SML CURD
# 12                            CHEESE,COTTAGE,CRMD,W/FRUIT
# 13       CHEESE,COTTAGE,NONFAT,UNCRMD,DRY,LRG OR SML CURD
# 14                       CHEESE,COTTAGE,LOWFAT,2% MILKFAT
# 15                       CHEESE,COTTAGE,LOWFAT,1% MILKFAT
# ...

# %%
df.Descrip
# Out:
# 0                                          Butter, salted
# 1                              Butter, whipped, with salt
# 2                                   Butter oil, anhydrous
# 3                                            Cheese, blue
# 4                                           Cheese, brick
# 5                                            Cheese, brie
# 6                                       Cheese, camembert
# 7                                         Cheese, caraway
# 8                                         Cheese, cheddar
# 9                                        Cheese, cheshire
# 10                                          Cheese, colby
# 11          Cheese, cottage, creamed, large or small curd
# 12                   Cheese, cottage, creamed, with fruit
# 13      Cheese, cottage, nonfat, uncreamed, dry, large...
# 14                    Cheese, cottage, lowfat, 2% milkfat
# 15                    Cheese, cottage, lowfat, 1% milkfat
# ...
