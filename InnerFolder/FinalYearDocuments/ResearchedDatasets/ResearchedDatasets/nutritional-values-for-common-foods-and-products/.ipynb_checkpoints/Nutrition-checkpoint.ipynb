# %%
import pandas as pd

#read in all the data from the csv file to the dataframe 
df = pd.read_csv("nutrition.csv")

df.saturated_fat.fillna("0g",inplace = True)

#gather the needed data from the dataframe and split them into the accrding dataframes, such as the fat dataframe
df2 = df[['Id','name','serving_size','calories','total_fat','saturated_fat','cholesterol','protein','alanine','arginine',
          'aspartic_acid','cystine','glutamic_acid','glycine','histidine','hydroxyproline','isoleucine','leucine','lysine',
          'methionine', 'phenylalanine', 'proline','serine','threonine','tryptophan','tyrosine','valine','carbohydrate',
          'fiber','sugars','fructose', 'galactose','glucose','lactose','maltose','sucrose','fat','saturated_fatty_acids',
          'monounsaturated_fatty_acids','polyunsaturated_fatty_acids', 'fatty_acids_total_trans','water']]

FatDF = df[['Id','name','serving_size','total_fat','saturated_fat','cholesterol','saturated_fatty_acids',
            'monounsaturated_fatty_acids','polyunsaturated_fatty_acids', 'fatty_acids_total_trans']]

CarbsDF = df[['Id', 'name','serving_size','carbohydrate','sugars','fructose', 'galactose',
              'glucose','lactose','maltose','sucrose']]

FiberDF = df[['Id','name','serving_size','fiber']]

NonEssentialProteinDF = df[['Id','name','serving_size','protein','alanine','arginine',
                            'aspartic_acid','cystine','glutamic_acid',
                            'glycine','hydroxyproline','proline','serine','tyrosine']]

EssentialProteinDF = df[['Id','name','serving_size','protein','histidine','isoleucine',
                         'leucine','lysine','methionine','phenylalanine',
                         'threonine','tryptophan','valine']]

WaterDF = df[['Id','name',"serving_size",'water']]

df.head()
# Out:
#    Id             name serving_size  calories total_fat saturated_fat  \
# 0   0       Cornstarch        100 g       381      0.1g            0g
# 1   1     Nuts, pecans        100 g       691       72g          6.2g
# 2   2    Eggplant, raw        100 g        25      0.2g            0g
# 3   3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4   4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %%
for key in df2.columns:
    print(df2[key].isnull().sum())
    print(df2[key].count())
    print((df2[key].isnull().sum() * 100) /
          (df2[key].isnull().sum() + df2[key].count()))
    print("\n")
# Out:
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 1590
# 7199
# 18.09079531232222
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0
#
#
# 0
# 8789
# 0.0

# %%
df2.to_csv("nutrition_version2.csv")

##########################################################

FatDF.to_csv("FATDF.csv")

CarbsDF.to_csv("CarbsDF.csv")

FiberDF.to_csv("FiberDF.csv")

NonEssentialProteinDF.to_csv("NonEssentialProteinDF.csv")

EssentialProteinDF.to_csv("EssentialProteinDF.csv")

WaterDF.to_csv("WaterDF.csv")

# %%
df2.head()
# Out:
#    Id             name serving_size  calories total_fat saturated_fat  \
# 0   0       Cornstarch        100 g       381      0.1g           NaN
# 1   1     Nuts, pecans        100 g       691       72g          6.2g
# 2   2    Eggplant, raw        100 g        25      0.2g           NaN
# 3   3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4   4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol  protein  alanine arginine  ... galactose glucose lactose  \
# 0           0   0.26 g  0.019 g  0.012 g  ...         0       0       0
# 1           0   9.17 g  0.397 g  1.177 g  ...         0  0.04 g  0.00 g
# 2           0   0.98 g  0.051 g  0.057 g  ...         0  1.58 g       0
# 3           0  13.30 g  0.747 g  0.517 g  ...    0.00 g  0.73 g  0.00 g
# 4         1mg   1.10 g        0        0  ...         0       0       0
#
#   maltose sucrose      fat saturated_fatty_acids monounsaturated_fatty_acids  \
# 0       0       0   0.05 g               0.009 g                     0.016 g
# 1  0.00 g  3.90 g  71.97 g               6.180 g                    40.801 g
# 2       0  0.26 g   0.18 g               0.034 g                     0.016 g
# 3  0.01 g  0.62 g   2.38 g               0.449 g                     0.589 g
# 4       0       0   2.00 g               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans
# 0                     0.025 g                 0.00 mg
# 1                    21.614 g                 0.00 mg
# 2                     0.076 g                 0.00 mg
# 3                     1.071 g                       0
# 4                     0.080 g                 1.00 mg
#
# [5 rows x 41 columns]

# %%
#FatDF.head()
FatDF.sort_values(by=["monounsaturated_fatty_acids","polyunsaturated_fatty_acids"], 
                  ascending = False).head(20)#.to_csv("FATDF.csv")
# Out:
#         Id                                               name serving_size  \
# 8271  8271  Beef, braised, cooked, all grades, trimmed to ...        100 g
# 5599  5599  Infant Formula, powder, Infant, Premium, ENFAM...        100 g
# 6399  6399  Infant Formula, powder, Infant, Premium LIPIL,...        100 g
# 3181  3181          Fast Foods, with egg and sausage, biscuit        100 g
# 831    831                       Candies, semisweet chocolate        100 g
# 2041  2041                Egg, pasteurized, frozen, raw, yolk        100 g
# 8319  8319  Beef, braised, cooked, choice, trimmed to 0" f...        100 g
# 6315  6315  Cake, unenriched, other than all butter, comme...        100 g
# 6499  6499  Cake, enriched, other than all butter, commerc...        100 g
# 1870  1870                    Luncheon sausage, pork and beef        100 g
# 8630  8630  Lamb, roasted, cooked, trimmed to 1/8" fat, se...        100 g
# 3884  3884     Candies, made with butter, semisweet chocolate        100 g
# 2171  2171            Frankfurter, unheated, meat and poultry        100 g
# 8700  8700  Beef, raw, choice, trimmed to 1/8" fat, separa...        100 g
# 7754  7754  Beef, roasted, cooked, select, trimmed to 1/8"...        100 g
# 3464  3464   Snacks, baked, restructured, white, potato chips        100 g
# 245    245                                Spices, fennel seed        100 g
# 4507  4507  MURRAY, Chocolate Chip & Pecan Cookies, SUGAR ...        100 g
# 6964  6964  Infant formula, with ARA and DHA, powder, with...        100 g
# 1716  1716                   Snacks, rice-based, oriental mix        100 g
#
#      total_fat saturated_fat cholesterol saturated_fatty_acids  \
# 8271       21g            9g        96mg               9.009 g
# 5599       27g           11g           0              11.161 g
# 6399       27g           11g           0              11.161 g
# 3181       21g          6.4g       161mg               6.449 g
# 831        30g           18g           0              17.750 g
# 2041       26g          8.6g       991mg               8.615 g
# 8319       21g          8.5g       100mg               8.532 g
# 6315       18g          4.6g        58mg               4.647 g
# 6499       18g          4.6g        58mg               4.647 g
# 1870       21g          7.6g        64mg               7.620 g
# 8630       26g           13g        99mg              12.820 g
# 3884       30g           18g        18mg              17.530 g
# 2171       24g          7.6g        78mg               7.583 g
# 8700       21g          9.3g        70mg               9.265 g
# 7754       24g          9.4g        85mg               9.380 g
# 3464       18g          2.6g           0               2.631 g
# 245        15g          0.5g           0               0.480 g
# 4507       31g          9.6g         7mg               9.600 g
# 6964       27g           11g        17mg              11.221 g
# 1716       26g          3.8g           0               3.785 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 8271                     9.997 g                     0.884 g
# 5599                     9.987 g                     5.213 g
# 6399                     9.987 g                     5.213 g
# 3181                     9.985 g                     2.967 g
# 831                      9.966 g                     0.966 g
# 2041                     9.956 g                     4.827 g
# 8319                     9.954 g                     0.856 g
# 6315                     9.935 g                     2.251 g
# 6499                     9.935 g                     2.251 g
# 1870                     9.930 g                     2.050 g
# 8630                     9.930 g                     1.190 g
# 3884                     9.930 g                     0.950 g
# 2171                     9.929 g                     5.386 g
# 8700                     9.929 g                     0.921 g
# 7754                     9.920 g                     0.960 g
# 3464                     9.910 g                     4.234 g
# 245                      9.910 g                     1.690 g
# 4507                     9.900 g                     9.800 g
# 6964                     9.899 g                     5.240 g
# 1716                     9.860 g                    10.643 g
#
#      fatty_acids_total_trans
# 8271                96.00 mg
# 5599                 0.00 mg
# 6399                 0.00 mg
# 3181               161.00 mg
# 831                  0.00 mg
# 2041               991.00 mg
# 8319               100.00 mg
# 6315                58.00 mg
# 6499                58.00 mg
# 1870                64.00 mg
# 8630                99.00 mg
# 3884                18.00 mg
# 2171                78.00 mg
# 8700                70.00 mg
# 7754                85.00 mg
# 3464                 0.00 mg
# 245                  0.00 mg
# 4507                 7.00 mg
# 6964                17.00 mg
# 1716                 0.00 mg

# %%
#CarbsDF.head()
CarbsDF.sort_values(by=["fructose","galactose","glucose","lactose","maltose","sucrose"], 
                    ascending = False).head(20)#.to_csv("CarbsDF.csv")

# %%
#NonEssentialProteinDF.head(20) 
NonEssentialProteinDF.sort_values(by=["alanine","arginine","aspartic_acid","cystine","glutamic_acid","glycine",
                                      "hydroxyproline","proline","serine","tyrosine"],
                                  ascending = False).head(20)#.to_csv("NonEssentialProteinDF.csv")

# %%
#EssentialProteinDF.head(20)
EssentialProteinDF.sort_values(by=["histidine","isoleucine","leucine","lysine","methionine","phenylalanine","threonine",
                                   "tryptophan","valine"],ascending = False).head(20)#.to_csv("EssentialProteinDF.csv")

# %%
#FiberDF.head()
FiberDF.sort_values(by='fiber',ascending = False).head(20)#.to_csv("FiberDF.csv")
# Out:
#         Id                                               name serving_size  \
# 1930  1930                     Snacks, cheese-flavor, popcorn        100 g
# 2467  2467              Bananas, or banana powder, dehydrated        100 g
# 1257  1257                            Nuts, blanched, almonds        100 g
# 186    186                               Grape leaves, canned        100 g
# 3556  3556   Cereals, dry, Whole Wheat Natural Cereal, QUAKER        100 g
# 5274  5274  Cereals ready-to-eat, KELLOGG'S KRAVE chocolat...        100 g
# 6402  6402  Cereals ready-to-eat, Natural Granola Apple Cr...        100 g
# 4161  4161  Incaparina, unprepared, dry mix (corn and soy ...        100 g
# 6490  6490  Nuts, packaged, flaked, sweetened, dried (desi...        100 g
# 5186  5186  KELLOGG'S, Sour Cream & Onion, Cracker Chips, ...        100 g
# 3019  3019         KELLOGG'S, Savory Herb Crackers, SPECIAL K        100 g
# 3018  3018        Hazelnuts, beaked (Northern Plains Indians)        100 g
# 3515  3515   Cereals ready-to-eat, KELLOGG SCOOBY-DOO! cereal        100 g
# 4729  4729  Cereals, Regular, Instant Oatmeal Organic, QUAKER        100 g
# 4308  4308  PEPPERIDGE FARM, Whole Grain Honey Whole Wheat...        100 g
# 77      77                              Figs, uncooked, dried        100 g
# 3139  3139         PEPPERIDGE FARM, Whole Grain Oatmeal Bread        100 g
# 3948  3948      Tortillas, whole wheat, ready-to-bake or -fry        100 g
# 806    806                       Kanpyo, (dried gourd strips)        100 g
# 6137  6137  Cereals ready-to-eat, presweetened with nuts a...        100 g
#
#       fiber
# 1930  9.9 g
# 2467  9.9 g
# 1257  9.9 g
# 186   9.9 g
# 3556  9.9 g
# 5274  9.9 g
# 6402  9.9 g
# 4161  9.9 g
# 6490  9.9 g
# 5186  9.8 g
# 3019  9.8 g
# 3018  9.8 g
# 3515  9.8 g
# 4729  9.8 g
# 4308  9.8 g
# 77    9.8 g
# 3139  9.8 g
# 3948  9.8 g
# 806   9.8 g
# 6137  9.7 g

# %%
#WaterDF.head()
WaterDF.sort_values(by = "water", ascending = False).head(20)
# Out:
#         Id                                               name serving_size  \
# 1240  1240                            Water, generic, bottled        100 g
# 4668  4668  Beverages, DANNON, non-carbonated, bottled, water        100 g
# 6768  6768  Beverages, DANNON Fluoride To Go, non-carbonat...        100 g
# 3460  3460   Beverages, EVIAN, non-carbonated, bottled, water        100 g
# 6091  6091  Beverages, AQUAFINA, PEPSI, non-carbonated, bo...        100 g
# 7403  7403  Beverages, non-carbonated, bottled, water, DAS...        100 g
# 7721  7721  Beverages,,Gerolsteiner naturally sparkling mi...        100 g
# 8558  8558  Beverages, mineral bottled water, naturally sp...        100 g
# 2237  2237             Beverages, regular, brewed, green, tea        100 g
# 2828  2828       Beverages, decaffeinated, brewed, green, tea        100 g
# 888    888                        Beverages, well, tap, water        100 g
# 1753  1753                   Beverages, club soda, carbonated        100 g
# 1726  1726                   Beverages, municipal, tap, water        100 g
# 1780  1780                    Beverages, drinking, tap, water        100 g
# 4899  4899  Babyfood, without added fluoride., GERBER, bot...        100 g
# 1488  1488                 Beverages, PERRIER, bottled, water        100 g
# 5713  5713  Beverages, assorted flavors, calorie-free, Pow...        100 g
# 4576  4576  Beverages, unsweetened, ready to drink, green,...        100 g
# 7795  7795  Water, sweetened with low calorie sweetener, n...        100 g
# 1997  1997                     Beverages, brewed, Oolong, tea        100 g
#
#         water
# 1240  99.98 g
# 4668  99.98 g
# 6768  99.97 g
# 3460  99.97 g
# 6091  99.97 g
# 7403  99.96 g
# 7721  99.95 g
# 8558  99.95 g
# 2237  99.93 g
# 2828  99.93 g
# 888   99.90 g
# 1753  99.90 g
# 1726  99.90 g
# 1780  99.90 g
# 4899  99.90 g
# 1488  99.90 g
# 5713  99.89 g
# 4576  99.88 g
# 7795  99.85 g
# 1997  99.84 g

# %%
#creating the datasets from the main one part two
df2.sort_values(by = 'water', ascending = False).head(20).to_csv(datasetsFolder + "WaterDF.csv")

# %%
datasetsFolder = "./NewerDatasets/"

# %%
df2.sort_values(by = ["monounsaturated_fatty_acids","polyunsaturated_fatty_acids"], 
                ascending = False).head(20).to_csv(datasetsFolder + "FatDF.csv")

# %%
df2.sort_values(by = ["fructose","galactose","glucose","lactose","maltose","sucrose"], 
                ascending = False).head(20).to_csv(datasetsFolder + "CarbsDF.csv")

# %%
df2.sort_values(by=["alanine","arginine","aspartic_acid","cystine","glutamic_acid","glycine","hydroxyproline","proline",
                    "serine","tyrosine"],ascending = False).head(20).to_csv(datasetsFolder +"NonEssentialProteinDF.csv")

# %%
df2.sort_values(by=["histidine","isoleucine","leucine","lysine","methionine","phenylalanine","threonine","tryptophan",
                    "valine"],ascending = False).head(20).to_csv(datasetsFolder +"EssentialProteinDF.csv")

# %%
#FiberDF.sort_values(by='fiber',ascending = False).head(20).to_csv("FiberDF.csv")
df2.sort_values(by='fiber',ascending = False).head(20).to_csv(datasetsFolder +"FiberDF.csv")
