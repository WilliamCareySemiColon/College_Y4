# %%
"""This programme is dedecated to the amount of resources that is needed per person per gender per day"""
import pandas as pd

df1 = pd.read_csv("recommended_daily_macronutrients.csv")

df2 = pd.read_csv("recommended_daily_nutrients.csv")

df1
# Out:
#                                             Substance  \
# 0                                            Water[i]
# 1                                       Carbohydrates
# 2                                         Protein[ii]
# 3                                               Fiber
# 4                                                 Fat
# 5   Linoleic acid, an omega-6 fatty acid (polyunsa...
# 6   alpha-Linolenic acid, an omega-3 fatty acid (p...
# 7                                         Cholesterol
# 8                                   Trans fatty acids
# 9                               Saturated fatty acids
# 10                                        Added sugar
#
#                                        Amount (males) Amount (females)  \
# 0                                           3.7 L/day        2.7 L/day
# 1                                           130 g/day        130 g/day
# 2                                            56 g/day         46 g/day
# ...

# %%
df2
# Out:
#                     Nutrient  EAR  Highest RDA/AI  UL[7] Unit  \
# 0                  Vitamin A  625           900.0   3000   µg
# 1               Thiamin (B1)    1             1.2     ND   mg
# 2            Riboflavin (B2)  1.1             1.3     ND   mg
# 3                Niacin (B3)   12            16.0     35   mg
# 4      Pantothenic acid (B5)   NE             5.0     ND   mg
# 5                 Vitamin B6  1.1             1.3    100   mg
# 6                Biotin (B7)   NE            30.0     ND   µg
# 7                Folate (B9)  320           400.0   1000   µg
# 8       Cyanocobalamin (B12)    2             2.4     ND   µg
# 9                  Vitamin C   75            90.0   2000   mg
# 10                 Vitamin D   10            15.0    100   µg
# 11  α-tocopherol (Vitamin E)   12            15.0   1000   mg
# 12                 Vitamin K   NE           120.0     ND   µg
# 13                   Choline   NE           550.0   3500   mg
# ...
