# %%
import pandas as pd

# %%
data_set = pd.read_csv("dataset.csv")

data_set.head()
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# 5    1  158         audi     gas    std  four        sedan  fwd  front  105.8
# 6    1    ?         audi     gas    std  four        wagon  fwd  front  105.8
# 7    1  158         audi     gas  turbo  four        sedan  fwd  front  105.8
# 8    0    ?         audi     gas  turbo   two    hatchback  4wd  front   99.5
# 9    2  192          bmw     gas    std   two        sedan  rwd  front  101.2
# 10   0  192          bmw     gas    std  four        sedan  rwd  front  101.2
# ...

# %%
file_reader = open("feature_names.txt")

text_reader = file_reader.read()

print(text_reader)
# Out:
# symboling
# normalized-losses
# make
# fuel-type
# aspiration
# num-of-doors
# body-style
# drive-wheels
# engine-location
# wheel-base
# length
# width
# height
# curb-weight
# engine-type
# num-of-cylinders
# engine-size
# fuel-system
# bore
# stroke
# compression-ratio
# horsepower
# peak-rpm
# city-mpg
# highway-mpg
# price

# %%
data_set.columns = [text_reader.split("\n")]

print(data_set.columns)
# Out:
# MultiIndex(levels=[['aspiration', 'body-style', 'bore', 'city-mpg', 'compression-ratio', 'curb-weight', 'drive-wheels', 'engine-location', 'engine-size', 'engine-type', 'fuel-system', 'fuel-type', 'height', 'highway-mpg', 'horsepower', 'length', 'make', 'normalized-losses', 'num-of-cylinders', 'num-of-doors', 'peak-rpm', 'price', 'stroke', 'symboling', 'wheel-base', 'width']],
#            codes=[[23, 17, 16, 11, 0, 19, 1, 6, 7, 24, 15, 25, 12, 5, 9, 18, 8, 10, 2, 22, 4, 14, 20, 3, 13, 21]])

# %%
data_set
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           1                 ?  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2                 ?         audi       gas        std
# 5           1               158         audi       gas        std
# 6           1                 ?         audi       gas        std
# 7           1               158         audi       gas      turbo
# 8           0                 ?         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
data_set("normalized-losses")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e4f2dd4986a2> in <module>
# ----> 1 data_set("normalized-losses")
#
# TypeError: 'DataFrame' object is not callable

# %%
data_set2 = pd.read_csv("dataset.csv", na_values = "?")

data_set2.columns = [text_reader.split("\n")]

data_set2.head()

data_set2
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           1               NaN  alfa-romero       gas        std
# 2           2             164.0         audi       gas        std
# 3           2             164.0         audi       gas        std
# 4           2               NaN         audi       gas        std
# 5           1             158.0         audi       gas        std
# 6           1               NaN         audi       gas        std
# 7           1             158.0         audi       gas      turbo
# 8           0               NaN         audi       gas      turbo
# 9           2             192.0          bmw       gas        std
# 10          0             192.0          bmw       gas        std
# 11          0             188.0          bmw       gas        std
# 12          0             188.0          bmw       gas        std
# ...

# %%
data_set2["normalized-losses"].count()
# Out:
# normalized-losses    164
# dtype: int64

# %%
data_set2["normalized-losses"].max()
# Out:
# normalized-losses    256.0
# dtype: float64

# %%
data_set2["normalized-losses"].min()
# Out:
# normalized-losses    65.0
# dtype: float64

# %%
data_set2["normalized-losses"].std()
# Out:
# normalized-losses    35.442168
# dtype: float64

# %%
data_set2["normalized-losses"].describe()
# Out:
#       normalized-losses
# count        164.000000
# mean         122.000000
# std           35.442168
# min           65.000000
# 25%           94.000000
# 50%          115.000000
# 75%          150.000000
# max          256.000000

# %%
#25th percentile 
data_set2["normalized-losses"].quantile(.25)
# Out:
# normalized-losses    94.0
# Name: 0.25, dtype: float64

# %%
#75th percentile 
data_set2["normalized-losses"].quantile(.75)
# Out:
# normalized-losses    150.0
# Name: 0.75, dtype: float64

# %%
print(data_set2.make.count())

data_set2["make"].unique()
# Out:
# make    204
# dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-a53478b7623d> in <module>
#       1 print(data_set2.make.count())
#       2
# ----> 3 data_set2["make"].unique()
#
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5055             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5056                 return self[name]
# -> 5057             return object.__getattribute__(self, name)
#    5058
#    5059     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
ds = pd.read_csv("dataset.csv", na_values = "?")

ds.columns = text_reader.split("\n")

#ds.columns

#text_reader.split("\n")

ds["make"].unique()

#ds.groupby("make").make
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
ds["make"].mode()
# Out:
# 0    toyota
# dtype: object

# %%
ds["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# jaguar            3
# alfa-romero       2
# renault           2
# mercury           1
# Name: make, dtype: int64
